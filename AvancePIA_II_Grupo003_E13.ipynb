# %% [markdown]
# # 1. FIFA 20 complete player dataset

# %% [markdown]
# ## 2. Descripción de los datos
# Tablas con datos de tipo texto y número que indican características específicas de los jugadores que van desde datos personales hasta el nivel de habilidades con las que cuenta.

# %%
import pandas as ps
import numpy as ny

# %%
df= ps.read_csv("players_20.csv")

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %% [markdown]
# ## 3. Justificación del uso de datos
#
# #### a)	Cuales son las características que les llamaron la atención de los datos. Que les hizo querer trabajar con ellos.
# De las cosas que más nos gustaron de los datos fue que nos parecieron bastante completos para cada jugador, y con todos estos datos tenemos la posibilidad de hacer una búsqueda bastante completa, planteando distintos escenarios en los cuales busquemos jugadores con las características que se ajusten a nuestras necesidades.
#
# #### b)	Que beneficio encuentran en trabajar con esos datos.
# Que las habilidades de los jugadores están expresados en números, es decir,  esta habilidad tiene una calificación del 1 al 100, entonces tener un número nos parece más útil que tener opiniones en texto ya que eso puede ser más difícil de descifrar que una calificación, el hecho de que esté expresado en número nos permite identificar de una manera más rápida si un jugador cuenta con una característica de su juego bien desarrollada, a que si tuviéramos otro tipo de valores como opiniones de expertos en donde tendríamos que aislar palabras clave como “bueno”, “malo”, etc., aunado a esto como mencionamos en el punto anterior son muchas las características evaluadas de cada jugador lo que nos amplía el panorama para buscar y encontrar a un jugador con las características y habilidades de juego que cumplan con nuestras necesidades.

# %% [markdown]
# ## 4. Mencionar los objetivos (principal y secundarios)
# #### a)	Principal:
# Desarrollar un programa que  nos ayude en la toma de decisiones para cuestiones en las que se busca la mejor opción que pueda suplir una necesidad de la mejor manera, no solo ajustándose a un presupuesto, sino que también busque las características deseadas y pueda entregar múltiples opciones.
# #### b)	Secundario:
# Llevar dicho programa no solo a la cuestión de compra de jugadores sino también a otras áreas en las que igual pueda funcionar y ayudar a las personas como por ejemplo en asesorías financieras ayudando a las personas a comprar un auto que se ajuste no solo a su presupuesto, sino que también tome en cuenta los gustos de las personas.

# %% [markdown]
# ## 1.

# %% [markdown]
# #### a. Mostrar datos sin manipular

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %% [markdown]
# #### b. Eliminar columanas no deseadas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

limpieza1=df.drop(['player_url', 'sofifa_id','dob','international_reputation','work_rate','real_face','player_tags','loaned_from','joined','nation_position','nation_jersey_number','player_traits','ls','st','rs','rw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb'], axis=1) 

f,ax=plt.subplots(figsize = (19,19))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

nivel = ps.DataFrame(limpieza1,columns = ["short_name","age","nationality","overall","height_cm","potential","weight_kg","value_eur","wage_eur","weak_foot"])
nivel
# Out:
#               short_name  age nationality  overall  height_cm  potential  \
# 0               L. Messi   32   Argentina       94        170         94
# 1      Cristiano Ronaldo   34    Portugal       93        187         93
# 2              Neymar Jr   27      Brazil       92        175         92
# 3               J. Oblak   26    Slovenia       91        188         93
# 4              E. Hazard   28     Belgium       91        175         91
# ...                  ...  ...         ...      ...        ...        ...
# 18273         Shao Shuai   22    China PR       48        186         56
# 18274       Xiao Mingjie   22    China PR       48        177         56
# 18275          Zhang Wei   19    China PR       48        186         56
# 18276       Wang Haijian   18    China PR       48        185         54
# 18277         Pan Ximing   26    China PR       48        182         51
#
#        weight_kg  value_eur  wage_eur  weak_foot
# ...

# %% [markdown]
# En la primera linea del cuadro de código (la que comienza con limpieza1), ahí  preparamos la tabla que queremos utilizar. Una vez que logramos  diferenciar a los jugadores en su respectiva posición, las columnas que eliminamos son columnas que contienden datos que no nos brindan información útil para nuestro obejitvo ya que reflejan características que no afectan ni el nivel, las habilidades, el precio, nada de lo que nos podría interesar a la hora de buscar a un jugador algunos de los datos que eliminamos fueron una columna llamada "player_url" en esta encontramos url de cada jugador el cual nos lleva a la página de sofifa (en este página se encuentramos datos del jugador).
#
# También quitamos la columna de "real_face" como nuestra base de datos proviene de los datos que se tiene para un videojuego de futbol en esta columna hay datos booleanos que nos indican si se ha escaneado la cara del jugador o no, cosa que no influye en ningun aspecto o característica de las que podríamos estar buscando.
#
# También borramos alganas columnas en las cuales nos aparecia el nivel del jugador en distintas posiciones pero como no estaban como número realmente eran columnas que no nos aportaban mucha información y que no son comparables con los otros niveles de habilidades que teniamos por lo que decidimos quitar estas columnas y algunas otras que como ya mencionamos no las consideramos relevantes para este proyecto.
#
# Despúes de realizar la limpieza de nuestra base de datos original nos topamos con el problema de que no hemos podido clasificar a los jugadores nuestra base de datos por posción esto resulta importante ya que como podremos apreciar en el siguiente punto de manipulación de los datos nulos hay columnas que solo contien datos para jugadores que no juegan en la posición de portero y es por eso que resulta imporatente poder dividirlos ya que por ejemplo para el nivel de un portero no afectan los mismos niveles de habilidades que para un defensa, un medio o un delantero, en vista de que nosotros no hemos podido hacer esta clasificación decidimos utilizar esta gráfica de correlación en la cual buscamos características que todos los jugadores tuvieran sin importar su posición, tomamos las que nosotros consideramos estuvieran más relacionadas con el nivel y otros datos básicos como el nombre por el que son conocidos los jugadores, su edad, nacionalidad, entre otros. Si bien estos datos no afectan directamente al nivel si pueden influir de manera cualitativa en el precio o en la perceptción de estos jugadores, entonces creamos una base con las características que seleccionamos para trabajar temporalmente con ella en lo que podemos lograr clasificar a los jugadores por posición o bien para trabajar con ella en caso de no poder clasificarlos con la diferencia de que sería una búsqueda menos detallada.

# %% [markdown]
# #### c. Correcta manipulación de los datos nulos dentro de la base de datos

# %%
df.isnull().any()
# Out:
# sofifa_id     False
# player_url    False
# short_name    False
# long_name     False
# age           False
#               ...
# lb             True
# lcb            True
# cb             True
# rcb            True
# rb             True
# Length: 104, dtype: bool

# %% [markdown]
# Despúes de realizar la práctica anterior en la que preparamos los datos o inclusive antes nosotros sabíamos que tenemos columnas en nuestra base de datos con valores nulos y lo que decidimos fue dejar algunas de esas columnas y quitar otras, primero las columnas con datos nulos que decidimos mantener son columnas que continen principalmente caracteríticas de todos los jugadores que no son porteros, entonces decidimos no deshacernos de esas columnas ya que son parte de las características que buscamos en un jugador o que repercuten de cierta manera en su nivel o precio.
#
# Luego tenemos las columnas con datos nulos de las cuales si nos deshicimos en nuestra base de datos estos datos en su mayoría fueron datos que de igual manera tenían la mayoría de los jugadores a execepción de los porteros en esta columnas encontrabamos el nivel que tenian los jugadores en otras posiciones y los porteros no tienen esa característica dentro del juego ellos no tienen un nivel en otras posiciones diferentes a la suya, pero a diferencia de las columnas con las mismas características que decidimos no quitar de nuestra base de datos estas columnas continen datos de tipo objeto que nos impiden comparar directamente esta columna con otras de tipo entero además de que no son significativas para las características podríamos estar buscando en un jugador desde nuestro punto de vista.

# %% [markdown]
# #### e. Crear un nuevo archivo con la base de datos editada

# %%
nivel.to_csv("tablapt.csv", index=False)

# %% [markdown]
# ## 2. Estadística básica de los datos:

# %% [markdown]
# #### a. Tomando en cuenta sus objetivos, inicia con algunos de los datos estadísticos básicos mostrados en la práctica 2.

# %%
nivel.describe()
# Out:
#                 age       overall     height_cm     potential     weight_kg  \
# count  18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean      25.283291     66.244994    181.362184     71.546887     75.276343
# std        4.656964      6.949953      6.756961      6.139669      7.047744
# min       16.000000     48.000000    156.000000     49.000000     50.000000
# 25%       22.000000     62.000000    177.000000     67.000000     70.000000
# 50%       25.000000     66.000000    181.000000     71.000000     75.000000
# 75%       29.000000     71.000000    186.000000     75.000000     80.000000
# max       42.000000     94.000000    205.000000     95.000000    110.000000
#
#           value_eur       wage_eur     weak_foot
# count  1.827800e+04   18278.000000  18278.000000
# mean   2.484038e+06    9456.942773      2.944250
# std    5.585481e+06   21351.714095      0.664656
# min    0.000000e+00       0.000000      1.000000
# ...

# %%
nivel.corr()
# Out:
#                 age   overall  height_cm  potential  weight_kg  value_eur  \
# age        1.000000  0.464305   0.081391  -0.262872   0.237169   0.081513
# overall    0.464305  1.000000   0.039945   0.646650   0.156522   0.638230
# height_cm  0.081391  0.039945   1.000000  -0.002432   0.768816   0.009527
# potential -0.262872  0.646650  -0.002432   1.000000  -0.011738   0.580868
# weight_kg  0.237169  0.156522   0.768816  -0.011738   1.000000   0.051782
# value_eur  0.081513  0.638230   0.009527   0.580868   0.051782   1.000000
# wage_eur   0.151031  0.573578   0.019547   0.475490   0.065946   0.858052
# weak_foot  0.073988  0.230276  -0.175200   0.171354  -0.128568   0.169084
#
#            wage_eur  weak_foot
# age        0.151031   0.073988
# overall    0.573578   0.230276
# height_cm  0.019547  -0.175200
# potential  0.475490   0.171354
# weight_kg  0.065946  -0.128568
# value_eur  0.858052   0.169084
# wage_eur   1.000000   0.149405
# weak_foot  0.149405   1.000000

# %% [markdown]
# #### b. Explicar a detalle porque se utilizó cada uno de ellos y comentar resultados al final. (Que es lo que me dicen estos datos con respecto a mis objetivos o planteamiento del problema)

# %% [markdown]
# 1.- Medidas de tendencia central:
#
# La primera tabla en la cual nos muestra la estadísticas básicas de las variables que consideramos importantes, como por ejemplo, podemos ver que la edad media es de 25 años, por lo que podemos decir que la edad promedio de los jugadores es buena ya que varios expertos catalogan dicha edad como importante ya que para esa edad es más notorio si un jugador está consolidado. También vemos que el valor promedio es de 2,484,038 euros por lo cual podría ser accesible para muchos equipos. Esta y las demás descripciones son pueden ser decisivas al momento de una compra de un jugador.

# %% [markdown]
# 2.-Correlación:
#
# Esta estadística nos ayuda a poder visualizar los datos de forma conjunta, por ejemplo podemos ver que la correlación entre la valoración del jugador (overall) y el precio en euros es 0.64 por lo que podemos decir que si existe una relación entre su valoración y su precio, no es fuerte, pero existe la relación. Por otro lado podemos ver que la relación entre su precio y su salario tienen una relación alta  (0.86)  por lo que podríamos decir que a mayor costo de jugador, mayor salario cobra y de igual manera podemos sacar conclusiones con algunas variables como la edad y la valoración, la edad y el precio, etcétera.

# %% [markdown]
# ## 3. Gráficas:

# %% [markdown]
# #### a. Tomando en cuenta los resultados de la estadística descriptiva básica y realicen al menos 4 gráficas que les ayude a entender mejor su base de datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# La primer gráfica que hicimos fue el mapa de correlación para ayudarnos a ver cuales de nuestros datos se relacionan más y con ellos ver como se comportan uno respecto a otro.

# %%
f,ax=plt.subplots(figsize = (7,7))
sns.heatmap(nivel.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# Lo primero que comparamos es el nivel del jugador con respecto a su precio (este dado en millonesde euros), hicimos dos gráficas en la primera es fácil notar que conforme sube el nivel su precio también sube pero también podemos observar que hay al menos un jugador con un nivel superior a 90 que no sube tanto como los jugadores más caros eso tal vez podría estar relacionado con la edad, el potencial del jugador, u otro factor, pero la cuestión es que si buscamos un jugador de nivel alto puede que no tenga que ser el más caro de todos.
#
# Despúes si dirigimos nuestra atención a la segunda gráfica tenemos los mismos datos solo que ahora agregamos una noción de la edad de los jugadores que como podemos ver si puede ser algo determinante a la hora de fijar un precio ya que si seguimos los colores hasta antes de los 30 años podemos ver que si hay jugadores con un valor muy alto, también vemos que tenemos muy pocos o ningún jugador registrado de más de 50 años, esta gráfica nos da también la perspectiva de que los jugadores más jovenes de cierto nivel son más caros que jugadores con el mismo nivel pero un poco más veteranos. Entonces esta gráfica nos ilustra muy bien que los jugadores jóvenes son más valiosos aunque en el correlograma no muestra tanta relación.

# %%
x = df["overall"]
y = df["value_eur"]

plt.bar(x,y,color='#e900a1')

sns.relplot(x='overall',y='value_eur',hue='age',palette = 'viridis', sizes=(15, 200),aspect=2.5,data=df)
plt.title('Overall Rating v  Value in Euros',fontsize = 20)
plt.xlabel('Overall Rating')
plt.ylabel('Value in Euros')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ae3150411e8> in <module>
# ----> 1 x = df["overall"]
#       2 y = df["value_eur"]
#       3
#       4 plt.bar(x,y,color='#e900a1')
#       5
#
# NameError: name 'df' is not defined

# %% [markdown]
# Lo primero que analizamos fue el valor de los jugadores con respecto a su nivel ya que despúes de ver nuestro mapa de correlación podemos notar que si se relacionan pero además nosotros sabemos que estas dos características que son muy determinantes a la hora de seleccionar un jugador, entonces pasamos a la primer gráfica en donde podemos ver algo que a lo mejor podíamos intuir desde antes que conforme aumenta el nivel del jugador su valor también aumenta, pero además en esa misma gráfica vemos que hay jugadores con un valor no tan cercano a los jugadores más caros pero si con un muy buen nivel entonces podemos empezar a considerar ese punto según lo que estamos buscando pero la cuestión es que ya vimos que este o estos jugadores con muy alto nivel y algo distante de jugadores más caros.
#
# Despúes en la segunda gráfica tenemos de igual manera el valor con respecto al nivel de los jugadores con la diferencia de que se agrega una noción de la edad entonces vemos que al igual que la primer gráfica vemos que conforme aumenta el nivel su valor también lo hace pero si ponemos atencion en la edad vemos que de los jugadores con el mismo nivel los jovenes son los más caros y esto se repite en todos los niveles y también vemos que los jugadores entre mas grandes tambien comienzan a estar más abajo que los demás jugadores con su mismo nivel, ya con estos datos podemos empezar a hacer un pequeño panorama de que pasaría si nosotros estamos buscando un jugador de nivel alto y támbien que tanto nos afecta la edad en este valor.

# %%
x = df["overall"]
y = df["wage_eur"]

plt.bar(x,y,color='#e900a1')

sns.relplot(x='overall',y='wage_eur',hue='age',palette = 'viridis', sizes=(15, 200),aspect=2.5,data=df)
plt.title('Overall Rating v  Wage in Euros',fontsize = 20)
plt.xlabel('Overall Rating')
plt.ylabel('Wage in Euros')
plt.show()

# %% [markdown]
# Después de comparar el nivel del jugador con su valor, pasamos a comparar su nivel con su salario (este esta dado en euros), como podemos ver en la primer gráfica se comporta de manera similar pero esta dada en euros vemos que de igual forma si sube el valor sube el salario lo que nos resulta algo no tan desacabellado.
#
# Lo interesante es que al igual que en la gráfica anterior encontrar jugadores de con un nivel muy alto pero que no cobran tanto como otros jugadores de alto nivel y aquí también podemos encontrar una posibilidad de tener un jugador con un nivel muy alto pero sin pagarle tanto, luego en nuestra segunda gráfica vemos una diferencia con la gráfica anterior que planteamos con las mismas características ya que en cuestión de sueldo de los jugadores con el mismo nivel los jovenes no siempre son los mejores pagados, pero se mantiene en ambas que estas últimas cuatro gráficas que mientras más nivel tenga el jugador más caro es adquirirlo y pagarle su salario.

# %%
x = df["age"]
y = df["overall"]

plt.bar(x,y,color='#e900a1')
plt.xlabel('Overall')
plt.ylabel('Age')

sns.jointplot(x ="overall", y = "age",data=df[df["overall"] < 100], kind='hex', gridsize=20,color="#e900a1")

# %% [markdown]
# Una vez que vimos como se comporta el valor y el salario con respecto al nivel y la edad tenemos estas dos gráficas la primera de barras que nos muestra que nivel tienen los jugadores de cierta edad esta parte es importante ya que vemos que los mejores jugadores estan entre los 30 y 35 años, jugadores de esa edad son considerados como veteranos e históricamente su nivel despues de los 35 años comienza a bajar lo que sería un punto a considerar si nosotros buscamos hacer una inversión grande en un jugador que mantenga un buen nivel por varios años o si solo nos interesa que lo mantenga pocos años.
#
# Despúes en la segunda gráfica, tenemos una gráfica que compara de los mismo que la gráfica anterior pero en esta nos muestra de además en que edad y nivel hay más jugadores en nuestra base de datos como vemos en un rango de nivel de entre aproximadamente 57 y 72, y en un rango de edad de entre 18 y 27 años es donde hay más jugadores, más jugadores se traducen directamente en más opciones la cuestión es si estos rangos cumplen con nuestras necesidades de lo que buscamos en un jugador o bien nosotros buscamos jugadores que se destaque o diferencien pero sean menos o más escasos, ahí es donde tenemos que empezar a interpretar nosotros la información en base a lo que buscamos.

# %%
x = df["potential"]
y = df["value_eur"]

plt.bar(x,y,color='#e900a1')

sns.relplot(x='potential',y='value_eur',hue='age',palette = 'viridis', sizes=(15, 200),aspect=2.5,data=df)
plt.title('Potential Rating  v  value in Euros',fontsize = 20)
plt.xlabel('Potential')
plt.ylabel('value in Euros')
plt.show()

sns.relplot(x='potential',y='wage_eur',hue='age',palette = 'viridis', sizes=(15, 200),aspect=2.5,data=df)
plt.title('Potential Rating  v  Wage in Euros',fontsize = 20)
plt.xlabel('Potential')
plt.ylabel('Wage in Euros')
plt.show()

# %% [markdown]
# Una vez que ya platicamos que los mejores jugadores son los que más valen y más ganan, y que además los jugadores más veteranos comienzan a disminuir su nivel a corto plazo, nos disponemos a revisar el potencial que tienen los jugadores con respecto a su valor en el mercado, su sueldo y su edad. En la primera gráfica tenemos una gráfica de barras en la cual solo vemos el comportamiento del potencial con respecto al valor y en esa gráfica podemos ver que se comporta muy parecida a las anterirores mientras sube el nivel (en este caso el nivel potencial) los jugadores son mas caros o tienen un salario más alto.
#
# Pero en la segunda y tercera gráfica comparamos el potencial con el valor y con el salario respectivamente pero ahora con una noción de la edad y es aquí donde vemos que si bien hay jugadores de más de 30 años buenos con un potencial muy alto vemos que hay jugadores más jovenes con un potencial muy alto también y esto nos puede ayudar a tomar una decisión entre si queremos un jugador que ya tenga un muy buen nivel, que es caro y tiene un sueldo alto como hemos visto, pero con el antecedente de que comenzara a disminuir su nivel a corto plazo, u optar por un jugador joven con un nivel no tan alto o inclusive pudidendo caer en un nivel bajo pero que como ya sabemos no tienen los salarios más altos de los jugadores que comparten su nivel y que tiene la posibilidad de subir su nivel a un nivel muy alto es ahí donde encontramos valiosa esta visualización y entra nuestro criterio para decidir en que jugador vamos a invertir el dinero.

# %%
plt.figure(dpi=125)
sns.countplot('team_position',data=df)
plt.xlabel('Team Positions')
plt.ylabel('Count')
plt.xticks(rotation=60)
plt.title('Count of Team Positions Players')
plt.show()

# %% [markdown]
# Despúes de ver la comparación de todo y comenzar a considerar nuestras necesidades aquí vemos de los jugadores que posición o rol juegan cada uno de estos dento de sus equipos como podemos ver porteros y defensas son en general de las posiciones en las que encontramos más jugadores. Como podemos ver hay muchos jugadores que son suplentes en sus equipos y reservas, esto es muy natural ya que un equipo la mayoría de las veces si sumamos a su equipo suplente y de reservas son más jugadores titulares, además de que el hecho de que los sean suplentes o pertenezcan al equipo de resevas no significa que no juege solo que no lo hacen en cada partido, esto también nos brinda infromación ya que es más fácil poder comprar a un jugador que juega un rol de suplente o esta en la reservas del equipo a uno que es titular ya que regularmente son los de mejor nivel y por lo visto más caros.

# %%
plt.figure(dpi=125)
sns.countplot('preferred_foot',data=df)
plt.xlabel('Preferred Foot Players')
plt.ylabel('Count')
plt.title('Count of Preferred Foot')
Right,Left=df.preferred_foot.value_counts()
print('Left Preferred',Left)
print('Right Preferred',Right)
plt.show()
# Out:
# Left Preferred 4318
# Right Preferred 13960

# %% [markdown]
# Aquí tenemos dos vistas en general del pie preferido de los jugadores y en la primer gráfica vemos que los jugadores que son derechos son más abundantes luego lo confirmamos ese hecho al ver la segunda gráfica en donde comparamos el nivel con el potencial pero dejándonos ver el pie preferido del los jugadores, y aquí vemos que no es tan determinante para el nivel o el potecial porque como vemos hay puntos de ambos colores en distintas posiciones y no se nota una diferencia clara entonces queda a nuestro criterio si el jugador es derecho o zurdo.

# %%
sklis_vec =['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 
             'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 
             'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 
             'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 
             'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 
             'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
             'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 
             'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']
sklis_vec
name_sklis_vec = ['short_name', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 
                 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 
                 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 
                 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 
                 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 
                 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
                 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 
                 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']

df_fifa20_attributes_names = df[name_sklis_vec]
df_fifa20_attributes_names
# Out:
#               short_name  pace  shooting  passing  dribbling  defending  \
# 0               L. Messi  87.0      92.0     92.0       96.0       39.0
# 1      Cristiano Ronaldo  90.0      93.0     82.0       89.0       35.0
# 2              Neymar Jr  91.0      85.0     87.0       95.0       32.0
# 3               J. Oblak   NaN       NaN      NaN        NaN        NaN
# 4              E. Hazard  91.0      83.0     86.0       94.0       35.0
# ...                  ...   ...       ...      ...        ...        ...
# 18273         Shao Shuai  57.0      23.0     28.0       33.0       47.0
# 18274       Xiao Mingjie  58.0      24.0     33.0       35.0       48.0
# 18275          Zhang Wei  54.0      35.0     44.0       45.0       48.0
# 18276       Wang Haijian  59.0      35.0     47.0       47.0       45.0
# 18277         Pan Ximing  60.0      32.0     51.0       45.0       47.0
#
#        physic  attacking_crossing  attacking_finishing  \
# ...

# %%
def plot_attributes(short_name):
    
    df_fifa20_attributes_names = df[name_sklis_vec]
    df_fifa20_attributes_names = df_fifa20_attributes_names.dropna()
    df_fifa20_attributes_names = df_fifa20_attributes_names.loc[df['short_name']==nom].reset_index()
    df_fifa20_attributes_names_transpose = df_fifa20_attributes_names.T
    y = df_fifa20_attributes_names_transpose.iloc[2:].index
    x = df_fifa20_attributes_names_transpose[0].iloc[2:]
    plt.figure(figsize= (10,15))
    plt.barh(y,x)

nom = str(input("Ingrese el Nombre corto del jugador :"))
plot_attributes(nom)

#https://www.kaggle.com/luizfernandogontijo/fifa20-football-analysis
# Out:
# Ingrese el Nombre corto del jugador :L. Messi

# %% [markdown]
# Y finalmente en nuestra parte de visualización tenemos una gráfica que nos muestra los niveles de las distintas características del jugador que ingresemos, esto nos puede ayudar a tomar una decisión en caso de que ya tengamos un nombre en mente y querramos ver que tivel de habilidades tiene este jugador.

# %% [markdown]
# #### b. Revisar si en esta etapa pueden empezar a concluir cosas de sus objetivos y planteamiento del problema.

# %% [markdown]
# En esta etapa pudimos ver que la parte de visualización si es de mucha ayuda para darnos un panorama general de nuestros datos y que tanto al estar realizando gráficas como al interpretarlas entra nuestro criterio y lo que realmente estamos buscando.
#
# La cuestión que tenemos que resolver es como poder clasificar a los jugadores por posición o mínimo poder separar a los a los porteros de las demás posiciones ya que los porteros tienen características específicas de su posición y que los jugadores no tienen y eso nos causa ruido en ciertas gráficas ya que son datos nulos, pero en caso de no podamos resolver esta cuestión nos planteamos una nueva base de datos que considera características que todos los jugadores tienen su excepción entonces en el peor de los casos en donde no hallemos la manera de hacer al menos dos grupos de porteros y no porteros podríamos trabajar con esta tabla, y en otras cuetiones pudimos apreciar algunas de las características que determinan que jugadores podemos tomar, y a falta de poder realizar grupos y poder ingresar datos nuestro equipo.
#
# Creemos que si podremos hacer una herramienta que nos permita tomar decisiones más informadas sobre a que jugador contratar, ya sea con nuestro plan inicial o con el plan emergente.

# %% [markdown]
# ### d. Conclusión global:

# %% [markdown]
# Como conclusión final sentimos que vamos avanzando bien en el proyecto ya que hemos podido hacer todas las prácticas anteriores a esta con lo que se nos pide. Si bien aún nos tenemos algunas dificultades, fuimos capaces de ver un plan B en caso de no poder resolverlo y este plan no modifica nuestros objetivos iniciales que son poder hacer una herramienta que nos permita tomar decisiones con respecto a que jugador nos es conveniente contratar con base a las características de cada jugador y nuestras necesidades. En vista de eso tenemos un problema por resolver pero eso no nos detuvo a seguir avanzando en el proyecto, entonces estamos con la disposición de seguir intentando más cosas y seguir haciendo más completa nuestra herramienta.
